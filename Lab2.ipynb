# %% [markdown]
# <a href="https://colab.research.google.com/github/chandana130305/ML_Lab/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
num = 9
angle_degrees = 45
print ("Square root : ",math.sqrt(num))
print ("Factorial : ",math.factorial(5))
print ("Logarithm base 10 : ",math.log10(100))
print ("Sine of 45 degrees : ",math.sin(math.radians(angle_degrees)))
print ("Value of PI : ",math.pi)
# Out:
# Square root :  3.0
# Factorial :  120
# Logarithm base 10 :  2.0
# Sine of 45 degrees :  0.7071067811865475
# Value of PI :  3.141592653589793

# %%
num1=4.3
num2 = 9.7
num3=-2.8
num4=5.0
print("Ceil of",num1," is : ",math.ceil(num1))
print("Ceil of",num2," is : ",math.ceil(num2))
print("Ceil of",num3," is : ",math.ceil(num3))
print("Ceil of",num4," is : ",math.ceil(num4))
# Out:
# Ceil of 4.3  is :  5
# Ceil of 9.7  is :  10
# Ceil of -2.8  is :  -2
# Ceil of 5.0  is :  5

# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50])
print(arr)
# Out:
# [10 20 30 40 50]
